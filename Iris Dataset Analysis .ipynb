# %% [markdown]
# # Dataset description
# The iris dataset consists of 5 columns:SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm,Species

# %%
# importing libraries for data analysis
import pandas as pd
import numpy as np
# importing libraries for data visualisation
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
#  reading the csv file and setting the column 'Id' as the index
df=pd.read_csv('Iris.csv',index_col='Id')
# df=df.drop(column=[''])- to delete a column
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Exploratory data analysis

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.4+ KB

# %%
# df['Species'].unique()
df['Species'].value_counts()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Id'>

# %%
plt.scatter(df['SepalLengthCm'],df['SepalWidthCm'])
plt.title('Iris dataset scatterplot')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
# colours ={'Iris-setosa':'r','Iris-virginica':'b','Iris-versicolor':'g'}
# for i in range(len(df1['SepalLengthCm'])):
#     plt.scatter(df1['SepalLengthCm'][i],df1['SepalWidthCm'][i],color=colours[df1['Species'][i]])
#     plt.legend(['Iris-setosa','Iris-virginica','Iris-versicolor'],loc='upper right')
species=['Iris-setosa','Iris-virginica','Iris-versicolor']
color=['red','blue','green']
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['SepalLengthCm'],x['SepalWidthCm'],color=color[i],label=species[i])
plt.legend(loc='upper right')
plt.title('Iris dataset scatterplot')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
plt.scatter(df['PetalLengthCm'],df['PetalWidthCm'])
plt.title('Iris dataset scatterplot')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
species=['Iris-setosa','Iris-virginica','Iris-versicolor']
color=['red','blue','green']
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['PetalLengthCm'],x['PetalWidthCm'],color=color[i],label=species[i])
plt.legend(loc='upper left')
plt.title('Iris dataset scatterplot')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'])
plt.title('Iris dataset scatterplot')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
species=['Iris-setosa','Iris-virginica','Iris-versicolor']
color=['red','blue','green']
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['SepalLengthCm'],x['PetalLengthCm'],color=color[i],label=species[i])
plt.legend(loc='upper left')
plt.title('Iris dataset scatterplot')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
plt.scatter(df['SepalWidthCm'],df['PetalWidthCm'])
plt.title('Iris dataset scatterplot')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
species=['Iris-setosa','Iris-virginica','Iris-versicolor']
color=['red','blue','green']
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['SepalWidthCm'],x['PetalWidthCm'],color=color[i],label=species[i])
plt.legend(loc='upper right')
plt.title('Iris dataset scatterplot')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
df_sw=df.groupby('Species').agg({'SepalWidthCm':np.average})
plt.scatter(df_sw['SepalWidthCm'],df_sw.index,color='red',label='Sepal Average Width')
df_sl=df.groupby('Species').agg({'SepalLengthCm':np.average})
plt.scatter(df_sl['SepalLengthCm'],df_sl.index,color='blue',label='Sepal Average Length')
df_pl=df.groupby('Species').agg({'PetalLengthCm':np.average})
plt.scatter(df_pl['PetalLengthCm'],df_pl.index,color='yellow',label='Petal Average Length')
df_pw=df.groupby('Species').agg({'PetalWidthCm':np.average})
plt.scatter(df_pw['PetalWidthCm'],df_pw.index,color='green',label='Petal Average Width')
plt.title('Average values of all the features')
plt.legend(fontsize='xx-small',loc='upper left',framealpha=0)
#  legend(bbox_to_anchor)=(0.5, 0.5)-can specify the particlar location at the plot
# similarly the maximum, minimum, mean, count can be plotted for the 3 categories

# %%
df_sw=df.groupby('Species').agg({'SepalWidthCm':np.max})
plt.scatter(df_sw['SepalWidthCm'],df_sw.index,color='red',label='Sepal Maximum Width')
df_sl=df.groupby('Species').agg({'SepalLengthCm':np.max})
plt.scatter(df_sl['SepalLengthCm'],df_sl.index,color='blue',label='Sepal Maximum  Length')
df_pl=df.groupby('Species').agg({'PetalLengthCm':np.max})
plt.scatter(df_pl['PetalLengthCm'],df_pl.index,color='yellow',label='Petal Maximum  Length')
df_pw=df.groupby('Species').agg({'PetalWidthCm':np.max})
plt.scatter(df_pw['PetalWidthCm'],df_pw.index,color='green',label='Petal Maximum  Width')
plt.title('Maximum values of all the features')
plt.legend(fontsize='xx-small',loc='upper left',framealpha=0)

# %%
df_sw=df.groupby('Species').agg({'SepalWidthCm':np.min})
plt.scatter(df_sw['SepalWidthCm'],df_sw.index,color='red',label='Sepal Minimum Width')
df_sl=df.groupby('Species').agg({'SepalLengthCm':np.min})
plt.scatter(df_sl['SepalLengthCm'],df_sl.index,color='blue',label='Sepal Minimum  Length')
df_pl=df.groupby('Species').agg({'PetalLengthCm':np.min})
plt.scatter(df_pl['PetalLengthCm'],df_pl.index,color='yellow',label='Petal Minimum  Length')
df_pw=df.groupby('Species').agg({'PetalWidthCm':np.min})
plt.scatter(df_pw['PetalWidthCm'],df_pw.index,color='green',label='Petal Minimum  Width')
plt.title('Minimum values of all the features')
plt.legend(fontsize='xx-small',loc='upper left',framealpha=0)

# %%
df['SepalLengthCm'].hist()
plt.title('Count of each Sepal Length value')
plt.xlabel('Sepal Length')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['PetalLengthCm'].hist()
plt.title('Count of each Petal Length value')
plt.xlabel('Petal Length')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['SepalWidthCm'].hist()
plt.title('Count of each Sepal width value')
plt.xlabel('Sepal Width')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['PetalWidthCm'].hist()
plt.title('Count of each Petal Width value')
plt.xlabel('Petal Width')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
corr=df.corr()
# print(corr.columns)
# corr.plot()
plt.imshow(corr.values)
plt.xticks(ticks=np.arange(0, 4, step=1),labels=corr.columns,rotation=45)
plt.yticks(ticks=np.arange(0, 4, step=1),labels=corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x155ecfd0>,
#   <matplotlib.axis.YTick at 0x155ecf90>,
#   <matplotlib.axis.YTick at 0x155cc0b0>,
#   <matplotlib.axis.YTick at 0x15612330>],
#  [Text(0, 0, 'SepalLengthCm'),
#   Text(0, 1, 'SepalWidthCm'),
#   Text(0, 2, 'PetalLengthCm'),
#   Text(0, 3, 'PetalWidthCm')])

# %%
fig,ax=plt.subplots(figsize=(5,4))
sns.heatmap(corr,annot=True,ax=ax)
ax.set_title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # Machine Learning Application

# %%
#LabelEncoder-converts labels into numerics
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# Id
# 1             5.1           3.5            1.4           0.2        0
# 2             4.9           3.0            1.4           0.2        0
# 3             4.7           3.2            1.3           0.2        0
# 4             4.6           3.1            1.5           0.2        0
# 5             5.0           3.6            1.4           0.2        0

# %%
#  training the dataset
from sklearn.model_selection import train_test_split
df1=df.reset_index(drop=True)
X=df1.drop(columns=['Species'])
Y=df1['Species']
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
model=LogisticRegression()

# %%
#model training
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#model prediction
predictions=model.predict(x_test)
print(predictions)
print(y_test)
# Out:
# [1 1 1 2 1 0 2 2 1 2 1 2 0 0 0 0 2 1 0 0 0 2 2 1 2 1 0 2 2 2 1 0 0 2 1 1 2
#  2 1 2 2 0 0 0 2]
# 52     1
# 75     1
# 93     1
# 120    2
# 72     1
# 15     0
# 122    2
# 100    2
# 69     1
# 129    2
# 99     1
# 124    2
# 48     0
# 1      0
# 11     0
# 23     0
# 146    2
# 79     1
# 40     0
# 17     0
# 47     0
# 109    2
# 141    2
# 74     1
# 138    2
# 67     1
# 31     0
# 107    2
# 114    2
# 83     1
# 53     1
# 46     0
# 32     0
# 142    2
# 65     1
# 85     1
# 105    2
# 111    2
# 86     1
# 110    2
# 125    2
# 9      0
# 16     0
# 29     0
# 77     1
# Name: Species, dtype: int32

# %%
#print metric to get performance
print('Accuracy:',model.score(x_test,y_test)*100)
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# Accuracy: 95.55555555555556
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.87      0.93        15
#            2       0.89      1.00      0.94        16
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
#
# 0.9555555555555556

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,predictions)
sns.heatmap(mat.T,square=True,annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## KNN-k nearest neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
#model training
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#model prediction
predictions=model.predict(x_test)
print(predictions)
print(y_test)
# Out:
# [1 1 1 2 2 0 2 2 1 2 1 2 0 0 0 0 2 1 0 0 0 2 2 1 2 1 0 2 2 2 1 0 0 2 1 1 2
#  2 1 2 2 0 0 0 2]
# 52     1
# 75     1
# 93     1
# 120    2
# 72     1
# 15     0
# 122    2
# 100    2
# 69     1
# 129    2
# 99     1
# 124    2
# 48     0
# 1      0
# 11     0
# 23     0
# 146    2
# 79     1
# 40     0
# 17     0
# 47     0
# 109    2
# 141    2
# 74     1
# 138    2
# 67     1
# 31     0
# 107    2
# 114    2
# 83     1
# 53     1
# 46     0
# 32     0
# 142    2
# 65     1
# 85     1
# 105    2
# 111    2
# 86     1
# 110    2
# 125    2
# 9      0
# 16     0
# 29     0
# 77     1
# Name: Species, dtype: int32

# %%
#print metric to get performance
print('Accuracy:',model.score(x_test,y_test)*100)
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# Accuracy: 93.33333333333333
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.80      0.89        15
#            2       0.84      1.00      0.91        16
#
#     accuracy                           0.93        45
#    macro avg       0.95      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45
#
# 0.9333333333333333

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,predictions)
sns.heatmap(mat.T,square=True,annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##  Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier  
model=DecisionTreeClassifier()

# %%
#model training
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#model prediction
predictions=model.predict(x_test)
print(predictions)
print(y_test)
# Out:
# [2 1 1 2 2 0 2 2 1 2 1 2 0 0 0 0 2 1 0 0 0 2 2 1 2 1 0 2 2 2 1 0 0 2 1 1 2
#  2 1 2 2 0 0 0 2]
# 52     1
# 75     1
# 93     1
# 120    2
# 72     1
# 15     0
# 122    2
# 100    2
# 69     1
# 129    2
# 99     1
# 124    2
# 48     0
# 1      0
# 11     0
# 23     0
# 146    2
# 79     1
# 40     0
# 17     0
# 47     0
# 109    2
# 141    2
# 74     1
# 138    2
# 67     1
# 31     0
# 107    2
# 114    2
# 83     1
# 53     1
# 46     0
# 32     0
# 142    2
# 65     1
# 85     1
# 105    2
# 111    2
# 86     1
# 110    2
# 125    2
# 9      0
# 16     0
# 29     0
# 77     1
# Name: Species, dtype: int32

# %%
#print metric to get performance
print('Accuracy:',model.score(x_test,y_test)*100)
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# Accuracy: 91.11111111111111
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.73      0.85        15
#            2       0.80      1.00      0.89        16
#
#     accuracy                           0.91        45
#    macro avg       0.93      0.91      0.91        45
# weighted avg       0.93      0.91      0.91        45
#
# 0.9111111111111111

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,predictions)
sns.heatmap(mat.T,square=True,annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## SVM-Support Vector Machine

# %%
from sklearn import svm
model=svm.SVC(kernel='linear',C=2,gamma='auto')

# %%
#model training
model.fit(x_train,y_train)
# Out:
# SVC(C=2, gamma='auto', kernel='linear')

# %%
#model prediction
predictions=model.predict(x_test)
print(predictions)
print(y_test)
# Out:
# [1 1 1 2 2 0 2 2 1 2 1 2 0 0 0 0 2 1 0 0 0 2 2 1 2 1 0 2 2 2 1 0 0 2 1 1 2
#  2 1 2 2 0 0 0 1]
# 52     1
# 75     1
# 93     1
# 120    2
# 72     1
# 15     0
# 122    2
# 100    2
# 69     1
# 129    2
# 99     1
# 124    2
# 48     0
# 1      0
# 11     0
# 23     0
# 146    2
# 79     1
# 40     0
# 17     0
# 47     0
# 109    2
# 141    2
# 74     1
# 138    2
# 67     1
# 31     0
# 107    2
# 114    2
# 83     1
# 53     1
# 46     0
# 32     0
# 142    2
# 65     1
# 85     1
# 105    2
# 111    2
# 86     1
# 110    2
# 125    2
# 9      0
# 16     0
# 29     0
# 77     1
# Name: Species, dtype: int32

# %%
#print metric to get performance
print('Accuracy:',model.score(x_test,y_test)*100)
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# Accuracy: 95.55555555555556
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.87      0.93        15
#            2       0.89      1.00      0.94        16
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
#
# 0.9555555555555556

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,predictions)
sns.heatmap(mat.T,square=True,annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Naive Bayes Classifier

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.pipeline import make_pipeline
# #creating model based on multinomial naives bayes
# model=make_pipeline(TfidfVectorizer(),MultinomialNB())

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB(priors = None)

# %%
#model training
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
#model prediction
predictions=model.predict(x_test)
print(predictions)
print(y_test)
# Out:
# [2 1 1 2 1 0 2 2 1 2 1 2 0 0 0 0 2 1 0 0 0 2 2 1 2 1 0 2 2 2 1 0 0 2 1 1 2
#  2 1 2 2 0 0 0 2]
# 52     1
# 75     1
# 93     1
# 120    2
# 72     1
# 15     0
# 122    2
# 100    2
# 69     1
# 129    2
# 99     1
# 124    2
# 48     0
# 1      0
# 11     0
# 23     0
# 146    2
# 79     1
# 40     0
# 17     0
# 47     0
# 109    2
# 141    2
# 74     1
# 138    2
# 67     1
# 31     0
# 107    2
# 114    2
# 83     1
# 53     1
# 46     0
# 32     0
# 142    2
# 65     1
# 85     1
# 105    2
# 111    2
# 86     1
# 110    2
# 125    2
# 9      0
# 16     0
# 29     0
# 77     1
# Name: Species, dtype: int32

# %%
#print metric to get performance
print('Accuracy:',model.score(x_test,y_test)*100)
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# Accuracy: 93.33333333333333
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.80      0.89        15
#            2       0.84      1.00      0.91        16
#
#     accuracy                           0.93        45
#    macro avg       0.95      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45
#
# 0.9333333333333333

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,predictions)
sns.heatmap(mat.T,square=True,annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Random Forest  Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(max_depth=10, min_samples_leaf=5, n_estimators=10, random_state=0)

# %%
#model training
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=5, n_estimators=10,
#                        random_state=0)

# %%
#model prediction
predictions=model.predict(x_test)
print(predictions)
print(y_test)
# Out:
# [2 1 1 2 2 0 2 2 1 2 1 2 0 0 0 0 2 1 0 0 0 2 2 1 1 1 0 2 2 2 1 0 0 2 1 1 2
#  2 1 2 2 0 0 0 2]
# 52     1
# 75     1
# 93     1
# 120    2
# 72     1
# 15     0
# 122    2
# 100    2
# 69     1
# 129    2
# 99     1
# 124    2
# 48     0
# 1      0
# 11     0
# 23     0
# 146    2
# 79     1
# 40     0
# 17     0
# 47     0
# 109    2
# 141    2
# 74     1
# 138    2
# 67     1
# 31     0
# 107    2
# 114    2
# 83     1
# 53     1
# 46     0
# 32     0
# 142    2
# 65     1
# 85     1
# 105    2
# 111    2
# 86     1
# 110    2
# 125    2
# 9      0
# 16     0
# 29     0
# 77     1
# Name: Species, dtype: int32

# %%
#print metric to get performance
print('Accuracy:',model.score(x_test,y_test)*100)
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# Accuracy: 88.88888888888889
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.92      0.73      0.81        15
#            2       0.79      0.94      0.86        16
#
#     accuracy                           0.89        45
#    macro avg       0.90      0.89      0.89        45
# weighted avg       0.90      0.89      0.89        45
#
# 0.8888888888888888

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,predictions)
sns.heatmap(mat.T,square=True,annot=True,fmt='d')
# Out:
# <AxesSubplot:>
